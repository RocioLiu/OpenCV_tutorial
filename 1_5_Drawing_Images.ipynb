# %% [markdown]
# <a href="https://colab.research.google.com/github/RocioLiu/OpenCV_tutorial/blob/master/1_5_Drawing_Images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Drawing images and shapes using OpenCV
#
# Let's start off my making a black square

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Create a black image
image = np.zeros((512,512,3), np.uint8)

# Can we make this in black and white?
image_bw = np.zeros((512,512), np.uint8)


cv2_imshow(image)
cv2_imshow(image_bw)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FD8FEA659E8>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FD8F5B1F748>

# %% [markdown]
# ### Let's draw a line over our black sqare
#
# cv2.line(image, starting cordinates, ending cordinates, color, thickness)

# %%
# Draw a diagonal blue line of thickness of 5 pixels
image = np.zeros((512,512,3), np.uint8)
cv2.line(image, (0,0), (511,511), (255,127,0), 5)
cv2_imshow(image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FD8FEA65940>

# %% [markdown]
# ### Let's now draw a rectangle
#
# cv2.rectangle(image, starting vertex, opposite vertex, color, thickness)
#
# starting vertex: the distance from the top left point

# %%
# Draw a Rectangle in
image = np.zeros((512,512,3), np.uint8)

cv2.rectangle(image, (100,100), (300,250), (127,50,127), -1)
cv2_imshow(image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FD913CB5860>

# %% [markdown]
# ### How about cirlcles?
#
# cv2.cirlce(image, center, radius, color, fill)

# %%
image = np.zeros((512,512,3), np.uint8)

cv2.circle(image, (200,300), 200, (148,196,55), 20)
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FD8FEA659E8>

# %% [markdown]
# ## And polygons?

# %%
image = np.zeros((512,512,3), np.uint8)

# Let's define four points
pts = np.array( [[10,50], [400,50], [90,200], [50,500]], np.int32)
print(pts.shape)
# Let's now reshape our points in form  required by polylines
pts = pts.reshape((-1,1,2))
print(pts.shape)

cv2.polylines(image, [pts], True, (0,0,255), 3)
cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# (4, 2)
# (4, 1, 2)
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FD8F5AB8080>

# %% [markdown]
# ### Let's even add text with cv2.putText
#
# cv2.putText(image, 'Text to Display', bottom left starting point, Font, Font Size, Color, Thickness)
#
# - FONT_HERSHEY_SIMPLEX, FONT_HERSHEY_PLAIN
# - FONT_HERSHEY_DUPLEX,FONT_HERSHEY_COMPLEX
# - FONT_HERSHEY_TRIPLEX, FONT_HERSHEY_COMPLEX_SMALL
# - FONT_HERSHEY_SCRIPT_SIMPLEX
# - FONT_HERSHEY_SCRIPT_COMPLEX

# %%
image = np.zeros((512,512,3), np.uint8)

cv2.putText(image, 'Hello World!', (50,200), cv2.FONT_HERSHEY_DUPLEX, 2, (100,170,0), 3)

cv2_imshow(image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FD8F57F4AC8>
